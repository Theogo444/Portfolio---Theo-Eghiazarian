# %%
from nba_api.stats.endpoints import leaguegamefinder, playercareerstats
from nba_api.stats.static import players
import pandas as pd
import time

# %% [markdown]
# Test pour Nikola Jokić (player_id = '203999')

# %%
NikoJokic = playercareerstats.PlayerCareerStats(player_id='203999')
jokic_df = NikoJokic.get_data_frames()[0]
print(jokic_df)
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203999   2015-16        00  1610612743               DEN        21.0
# 1      203999   2016-17        00  1610612743               DEN        22.0
# 2      203999   2017-18        00  1610612743               DEN        23.0
# 3      203999   2018-19        00  1610612743               DEN        24.0
# 4      203999   2019-20        00  1610612743               DEN        25.0
# 5      203999   2020-21        00  1610612743               DEN        26.0
# 6      203999   2021-22        00  1610612743               DEN        27.0
# 7      203999   2022-23        00  1610612743               DEN        28.0
# 8      203999   2023-24        00  1610612743               DEN        29.0
# 9      203999   2024-25        00  1610612743               DEN        30.0
# 10     203999   2025-26        00  1610612743               DEN        30.0
#
#     GP  GS   MIN  FGM  ...  FT_PCT  OREB  DREB   REB  AST  STL  BLK  TOV   PF  \
# 0   80  55  1733  307  ...   0.811   181   379   560  189   79   50  104  208
# 1   73  59  2038  494  ...   0.825   212   506   718  359   61   55  171  214
# 2   75  73  2443  504  ...   0.850   195   608   803  458   90   61  210  212
# 3   80  80  2504  616  ...   0.821   228   637   865  580  108   55  248  228
# 4   73  73  2335  565  ...   0.817   166   545   711  512   85   44  226  222
# 5   72  72  2488  732  ...   0.868   205   575   780  599   95   48  222  192
# 6   74  74  2476  764  ...   0.810   206   813  1019  584  109   63  281  191
# 7   69  69  2323  646  ...   0.822   167   650   817  678   87   47  247  174
# 8   79  79  2737  822  ...   0.817   223   753   976  708  108   68  237  194
# 9   70  70  2571  786  ...   0.800   200   692   892  716  127   45  230  160
# 10  14  14   483  152  ...   0.857    44   141   185  156   23   11   50   41
#
#      PTS
# 0    796
# 1   1221
# 2   1385
# 3   1604
# 4   1456
# 5   1898
# 6   2004
# 7   1690
# 8   2085
# 9   2071
# 10   408
#
# [11 rows x 27 columns]

# %% [markdown]
# Liste de tous les joueurs NBA sous forme de liste avec nom/prénom/full nom/id/is_active
# On Récupère tous les joueurs NBA (actifs + historiques)
# On utilise un sample_size = 200 car au delà de 200 et quelques requêtes, l'api bloque nos requêtes (erreur 403 : Forbiden)
# Ainsi, en raison de ce blocage au bout de 200 et quelques requêtes, on va boucler le programme pour obtenir les données des joueurs. Cependant, nous avons pu expérimenter que si nous faisons la boucle de manière classique, le programme nous bloque après la première boucle (avec n = sample_size itérations). Ainsi, nous avons rusé et nous avons donc fait une boucle mais de manière manuelle.
# Le processus est : i = 0, on exécute le programme, on récupère une liste de df de joueurs, on concatène. On a donc un df nommé df_all_players et on le transforme en csv (nba_players_i.csv) pour pouvoir stocker ces données sur l'ordinateur. Ainsi, on a les données de tous les joueurs que l'on souhaite séparées en 25 csv.
#
# Dans le même temps, on recense les erreurs pour pouvoir les analyser et les compter. Les erreurs viennent en grande majorité de joueurs qui sont renseignés comme étant en nba mais qui n'ont dans les fait pas joué de match nba (par exemple le rookie français Noa Essengué qui attend encore de joueur avec les chicago bulls même s'il est déjà dans l'effectif).

# %%
sample_size = 200
nba_players = players.get_players()



#On initialise une liste pour stocker les DataFrames
all_stats = []

count_error = 0
joueurs_error = []

# On boucle sur chaque joueur actif (on écarte les retraités)

Count_ex = int(len(nba_players)/sample_size)
print(Count_ex)
i = 0

sample_nba_players = nba_players[sample_size*i:sample_size*(i+1)]

for player in sample_nba_players:
    player_id = player['id']
    player_name = player['full_name']

    try:
        # Appel API pour les stats des joueurs
        career = playercareerstats.PlayerCareerStats(player_id=player_id)
        df = career.get_data_frames()[0]
        if int((df["SEASON_ID"][0])[5:]) < 26: #Filtrer les joueurs ayant commencé leur carrière NBA à partir de 2000 (< 26 ca veut dire qu'on va de 0 à 25 pour la première saison)
            # Premier DataFrame = stats par saison
            df['Player'] = player_name
            # On met les stats PAR MATCH (Per Game = PG) parce que c'est ça qui est parlant (avec le nombre de matchs joués)
            # On arrondit à 2 décimales pour les stats classiques, 1 pour les fautes
            df['PPG'] = (df['PTS'] / df['GP']).round(2)
            df['RPG'] = (df['REB'] / df['GP']).round(2)
            df['APG'] = (df['AST'] / df['GP']).round(2)
            df['SPG'] = (df['STL'] / df['GP']).round(2)
            df['BPG'] = (df['BLK'] / df['GP']).round(2)
            df['TOVPG'] = (df['TOV'] / df['GP']).round(2)
            df['PFPG'] = (df['PF'] / df['GP']).round(1)
            df['FG3MPG'] = (df['FG3M'] / df['GP']).round(2)
            df['FG3APG'] = (df['FG3A'] / df['GP']).round(2)
            df['FGMPG'] = (df['FGM'] / df['GP']).round(2)
            df['FGAPG'] = (df['FGA'] / df['GP']).round(2)
            df['OREBPG'] = (df['OREB'] / df['GP']).round(2)


            # On enlève les colonnes inutiles
            df = df.drop('PTS', axis=1)
            df = df.drop('REB', axis=1)
            df = df.drop('OREB', axis=1)
            df = df.drop('DREB', axis=1)
            df = df.drop('AST', axis=1)
            df = df.drop('STL', axis=1)
            df = df.drop('BLK', axis=1)
            df = df.drop('TOV', axis=1)
            df = df.drop('PF', axis=1)
            df = df.drop('FG3M', axis=1)
            df = df.drop('FG3A', axis=1)
            df = df.drop('FGM', axis=1)
            df = df.drop('FGA', axis=1)
            df = df.drop('LEAGUE_ID', axis=1)
            df = df.drop('TEAM_ID', axis=1)

            # On réorganise les colonnes
            df = df[['Player', 'SEASON_ID', 'PPG', 'RPG', 'APG', 'BPG', 'SPG'] + [col for col in df.columns if col not in ['PLAYER_ID', 'SEASON_ID', 'PPG', 'RPG', 'APG', 'BPG', 'SPG']]]

            print(df)
            
            all_stats.append(df)
                
            print(f"✓ {player_name} récupéré")
                    
    except Exception as e:
        count_error += 1
        joueurs_error.append(player_id)
        print(f"✗ Erreur pour {player_name}: {e}")
        continue
        
        #Pause pour éviter de surcharger l'API
    time.sleep(0.5)
    print(f"% de joueurs sélectionnés : {len(all_stats)/len(nba_players)*100:.2f} % \n Taille de l'échantillon : {len(nba_players)} \n Nombre d'erreurs : {count_error}", end='\r')


#print(joueurs_error)

#On Concatène tous les DataFrames
df_all_players = pd.concat(all_stats, ignore_index=True)

df_all_players.to_csv('nba_players_00.csv', index=False)

print(f"\nDataFrame final : {df_all_players.shape}")
print(df_all_players.head())
# Out:
# 25
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.00 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Alex Abrines   2016-17  5.97  1.26  0.59  0.12  0.54               OKC
# 1  Alex Abrines   2017-18  4.71  1.52  0.37  0.11  0.51               OKC
# 2  Alex Abrines   2018-19  5.32  1.55  0.65  0.19  0.55               OKC
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  68  ...   49   0.898  Alex Abrines   0.49   1.7    1.38
# 1        24.0  75  ...   46   0.848  Alex Abrines   0.33   1.7    1.12
# 2        25.0  31  ...   13   0.923  Alex Abrines   0.45   1.7    1.32
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    3.63  1.97   5.01    0.26
# 1    2.95  1.53   3.88    0.35
# 2    4.10  1.81   5.06    0.16
#
# [3 rows x 25 columns]
# ✓ Alex Abrines récupéré
# % de joueurs sélectionnés : 0.02 %
#  Taille de l'échantillon : 5135
#              Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Precious Achiuwa   2020-21  4.98  3.41  0.48  0.46  0.33               MIA
# 1  Precious Achiuwa   2021-22  9.10  6.48  1.12  0.56  0.51               TOR
# 2  Precious Achiuwa   2022-23  9.24  5.96  0.91  0.55  0.56               TOR
# 3  Precious Achiuwa   2023-24  7.72  5.44  1.76  0.48  0.64               TOR
# 4  Precious Achiuwa   2023-24  7.59  7.16  1.08  1.14  0.61               NYK
# 5  Precious Achiuwa   2023-24  7.64  6.58  1.31  0.92  0.62               TOT
# 6  Precious Achiuwa   2024-25  6.65  5.56  0.96  0.74  0.82               NYK
# 7  Precious Achiuwa   2025-26  6.67  4.67  0.83  0.50  0.83               SAC
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT            Player  TOVPG  PFPG  FG3MPG  \
# 0        21.0  61  ...  110   0.509  Precious Achiuwa   0.70   1.5    0.00
# 1        22.0  73  ...  131   0.595  Precious Achiuwa   1.15   2.1    0.77
# 2        23.0  55  ...  124   0.702  Precious Achiuwa   1.07   1.9    0.53
# 3        24.0  25  ...   42   0.571  Precious Achiuwa   1.16   1.6    0.52
# 4        24.0  49  ...   70   0.643  Precious Achiuwa   1.10   2.1    0.27
# 5        24.0  74  ...  112   0.616  Precious Achiuwa   1.12   1.9    0.35
# 6        25.0  57  ...   69   0.594  Precious Achiuwa   0.79   1.4    0.18
# 7        26.0   6  ...   11   0.545  Precious Achiuwa   0.50   1.2    0.00
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.02  2.03   3.74    1.20
# 1    2.14  3.63   8.26    2.00
# 2    1.96  3.56   7.35    1.82
# 3    1.88  3.12   6.80    2.00
# 4    1.02  3.20   6.10    2.88
# 5    1.31  3.18   6.34    2.58
# 6    0.63  2.88   5.74    1.77
# 7    1.00  2.83   4.83    1.67
#
# [8 rows x 25 columns]
# ✓ Precious Achiuwa récupéré
# % de joueurs sélectionnés : 0.04 %
#  Taille de l'échantillon : 5135
#        Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Alex Acker   2005-06  1.80  1.00  0.80  0.00  0.20               DET
# 1  Alex Acker   2008-09  1.29  0.29  0.14  0.14  0.29               DET
# 2  Alex Acker   2008-09  3.50  1.22  0.61  0.17  0.17               LAC
# 3  Alex Acker   2008-09  2.88  0.96  0.48  0.16  0.20               TOT
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT      Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        23.0   5  ...    0     0.0  Alex Acker   0.80   0.8    0.20    1.00
# 1        26.0   7  ...    2     0.5  Alex Acker   0.00   0.0    0.00    0.57
# 2        26.0  18  ...    8     0.5  Alex Acker   0.39   0.5    0.39    0.89
# 3        26.0  25  ...   10     0.5  Alex Acker   0.28   0.4    0.28    0.80
#
#   FGMPG  FGAPG  OREBPG
# 0  0.80   3.20    0.20
# 1  0.57   1.57    0.00
# 2  1.44   3.61    0.44
# 3  1.20   3.04    0.32
#
# [4 rows x 25 columns]
# ✓ Alex Acker récupéré
# % de joueurs sélectionnés : 0.06 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.06 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.06 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.06 %
#  Taille de l'échantillon : 5135
#         Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0   Quincy Acy   2012-13  4.00  2.66  0.38  0.52  0.45               TOR
# 1   Quincy Acy   2013-14  2.71  2.14  0.57  0.43  0.57               TOR
# 2   Quincy Acy   2013-14  2.71  3.59  0.43  0.41  0.34               SAC
# 3   Quincy Acy   2013-14  2.71  3.43  0.44  0.41  0.37               TOT
# 4   Quincy Acy   2014-15  5.85  4.43  1.00  0.32  0.40               NYK
# 5   Quincy Acy   2015-16  5.20  3.19  0.46  0.41  0.49               SAC
# 6   Quincy Acy   2016-17  2.17  1.33  0.00  0.00  0.00               DAL
# 7   Quincy Acy   2016-17  6.53  3.34  0.56  0.47  0.44               BKN
# 8   Quincy Acy   2016-17  5.84  3.03  0.47  0.39  0.37               TOT
# 9   Quincy Acy   2017-18  5.87  3.67  0.81  0.41  0.47               BKN
# 10  Quincy Acy   2018-19  1.70  2.50  0.80  0.40  0.10               PHX
#
#     PLAYER_AGE  GP  ...  FTA  FT_PCT      Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0         22.0  29  ...   38   0.816  Quincy Acy   0.59   1.8    0.03    0.07
# 1         23.0   7  ...    8   0.625  Quincy Acy   0.29   1.1    0.29    0.71
# 2         23.0  56  ...   45   0.667  Quincy Acy   0.50   2.0    0.04    0.18
# 3         23.0  63  ...   53   0.660  Quincy Acy   0.48   1.9    0.06    0.24
# 4         24.0  68  ...   97   0.784  Quincy Acy   0.88   2.2    0.26    0.88
# 5         25.0  59  ...   68   0.735  Quincy Acy   0.46   1.7    0.32    0.83
# 6         26.0   6  ...    3   0.667  Quincy Acy   0.33   1.5    0.17    1.17
# 7         26.0  32  ...   57   0.754  Quincy Acy   0.59   1.8    1.12    2.59
# 8         26.0  38  ...   60   0.750  Quincy Acy   0.55   1.8    0.97    2.37
# 9         27.0  70  ...   60   0.817  Quincy Acy   0.86   2.1    1.46    4.17
# 10        28.0  10  ...   10   0.700  Quincy Acy   0.40   2.4    0.20    1.50
#
#    FGMPG  FGAPG  OREBPG
# 0   1.45   2.59    1.03
# 1   0.86   2.00    0.71
# 2   1.07   2.27    1.20
# 3   1.05   2.24    1.14
# 4   2.24   4.87    1.16
# 5   2.02   3.63    1.10
# 6   0.83   2.83    0.33
# 7   2.03   4.78    0.56
# 8   1.84   4.47    0.53
# 9   1.86   5.21    0.57
# 10  0.40   1.80    0.30
#
# [11 rows x 25 columns]
# ✓ Quincy Acy récupéré
# % de joueurs sélectionnés : 0.08 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.08 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.08 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Hassan Adams   2006-07  2.85  1.26  0.21  0.07  0.28               NJN
# 1  Hassan Adams   2008-09  0.92  0.58  0.08  0.08  0.08               TOR
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  61  ...   36   0.667  Hassan Adams   0.36   0.8     0.0
# 1        25.0  12  ...    6   0.500  Hassan Adams   0.33   0.3     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.02  1.23   2.21    0.57
# 1    0.00  0.33   1.08    0.08
#
# [2 rows x 25 columns]
# ✓ Hassan Adams récupéré
# % de joueurs sélectionnés : 0.10 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Jaylen Adams   2018-19  3.18  1.76  1.91  0.15  0.41               ATL
# 1  Jaylen Adams   2020-21  0.29  0.43  0.29  0.00  0.00               MIL
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  34  ...    9   0.778  Jaylen Adams   0.82   1.3    0.74
# 1        25.0   7  ...    0   0.000  Jaylen Adams   0.00   0.1    0.00
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    2.18  1.12   3.24    0.32
# 1    0.29  0.14   1.14    0.00
#
# [2 rows x 25 columns]
# ✓ Jaylen Adams récupéré
# % de joueurs sélectionnés : 0.12 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Jordan Adams   2014-15  3.13  0.93  0.53  0.23  0.53               MEM
# 1  Jordan Adams   2015-16  3.50  1.00  1.50  0.00  1.50               MEM
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        20.0  30  ...   23   0.609  Jordan Adams   0.47   0.8    0.33
# 1        21.0   2  ...    5   0.600  Jordan Adams   1.00   1.0    0.00
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.83  1.17   2.87     0.3
# 1    0.50  1.00   3.00     0.0
#
# [2 rows x 25 columns]
# ✓ Jordan Adams récupéré
# % de joueurs sélectionnés : 0.14 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.14 %
#  Taille de l'échantillon : 5135
#           Player SEASON_ID    PPG    RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0   Steven Adams   2013-14   3.27   4.10  0.53  0.70  0.49               OKC
# 1   Steven Adams   2014-15   7.67   7.47  0.94  1.23  0.54               OKC
# 2   Steven Adams   2015-16   7.95   6.66  0.78  1.11  0.52               OKC
# 3   Steven Adams   2016-17  11.31   7.66  1.08  0.98  1.11               OKC
# 4   Steven Adams   2017-18  13.89   9.01  1.16  1.03  1.21               OKC
# 5   Steven Adams   2018-19  13.85   9.50  1.55  0.95  1.46               OKC
# 6   Steven Adams   2019-20  10.86   9.25  2.32  1.06  0.81               OKC
# 7   Steven Adams   2020-21   7.55   8.86  1.91  0.66  0.93               NOP
# 8   Steven Adams   2021-22   6.95  10.00  3.37  0.79  0.86               MEM
# 9   Steven Adams   2022-23   8.60  11.55  2.31  1.10  0.86               MEM
# 10  Steven Adams   2024-25   3.88   5.64  1.14  0.48  0.38               HOU
# 11  Steven Adams   2025-26   6.40   9.00  1.60  0.80  0.80               HOU
#
#     PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0         20.0  81  ...  136   0.581  Steven Adams   0.88   2.5    0.00
# 1         21.0  70  ...  205   0.502  Steven Adams   1.41   3.2    0.00
# 2         22.0  80  ...  196   0.582  Steven Adams   1.05   2.8    0.00
# 3         23.0  80  ...  257   0.611  Steven Adams   1.82   2.4    0.00
# 4         24.0  76  ...  286   0.559  Steven Adams   1.68   2.8    0.00
# 5         25.0  80  ...  292   0.500  Steven Adams   1.69   2.6    0.00
# 6         26.0  63  ...  201   0.582  Steven Adams   1.49   1.9    0.02
# 7         27.0  58  ...  135   0.444  Steven Adams   1.34   1.9    0.00
# 8         28.0  76  ...  199   0.543  Steven Adams   1.51   2.0    0.00
# 9         29.0  42  ...  129   0.364  Steven Adams   1.88   2.3    0.00
# 10        31.0  58  ...   93   0.462  Steven Adams   0.93   1.0    0.00
# 11        32.0  10  ...   21   0.762  Steven Adams   1.00   2.1    0.00
#
#     FG3APG FGMPG  FGAPG  OREBPG
# 0     0.00  1.15   2.28    1.75
# 1     0.03  3.10   5.70    2.84
# 2     0.00  3.26   5.32    2.74
# 3     0.01  4.68   8.19    3.51
# 4     0.03  5.89   9.37    5.05
# 5     0.02  6.01  10.11    4.89
# 6     0.05  4.49   7.59    3.29
# 7     0.05  3.26   5.31    3.67
# 8     0.01  2.76   5.05    4.59
# 9     0.02  3.74   6.26    5.10
# 10    0.03  1.57   2.88    2.86
# 11    0.00  2.40   4.10    4.80
#
# [12 rows x 25 columns]
# ✓ Steven Adams récupéré
# % de joueurs sélectionnés : 0.16 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.16 %
#  Taille de l'échantillon : 5135
#         Player SEASON_ID    PPG    RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Bam Adebayo   2017-18   6.91   5.52  1.46  0.59  0.46               MIA
# 1  Bam Adebayo   2018-19   8.89   7.28  2.24  0.79  0.87               MIA
# 2  Bam Adebayo   2019-20  15.92  10.21  5.11  1.29  1.14               MIA
# 3  Bam Adebayo   2020-21  18.70   8.95  5.41  1.03  1.17               MIA
# 4  Bam Adebayo   2021-22  19.07  10.07  3.39  0.79  1.43               MIA
# 5  Bam Adebayo   2022-23  20.39   9.17  3.20  0.81  1.17               MIA
# 6  Bam Adebayo   2023-24  19.25  10.38  3.92  0.93  1.14               MIA
# 7  Bam Adebayo   2024-25  18.08   9.60  4.32  0.68  1.26               MIA
# 8  Bam Adebayo   2025-26  19.88   8.12  2.88  0.25  1.00               MIA
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT       Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        20.0  69  ...  179   0.721  Bam Adebayo   0.96   2.0    0.00    0.10
# 1        21.0  82  ...  226   0.735  Bam Adebayo   1.48   2.5    0.04    0.18
# 2        22.0  72  ...  382   0.691  Bam Adebayo   2.83   2.5    0.03    0.19
# 3        23.0  64  ...  354   0.799  Bam Adebayo   2.64   2.3    0.03    0.12
# 4        24.0  56  ...  340   0.753  Bam Adebayo   2.64   3.1    0.00    0.11
# 5        25.0  75  ...  402   0.806  Bam Adebayo   2.49   2.8    0.01    0.16
# 6        26.0  71  ...  387   0.755  Bam Adebayo   2.28   2.2    0.21    0.59
# 7        27.0  78  ...  328   0.765  Bam Adebayo   2.06   2.1    1.01    2.83
# 8        28.0   8  ...   36   0.861  Bam Adebayo   2.00   1.6    2.00    5.88
#
#   FGMPG  FGAPG  OREBPG
# 0  2.52   4.93    1.71
# 1  3.41   5.93    2.01
# 2  6.11  10.97    2.44
# 3  7.12  12.50    2.22
# 4  7.25  13.02    2.45
# 5  8.03  14.85    2.45
# 6  7.46  14.32    2.24
# 7  6.92  14.27    2.37
# 8  7.00  15.50    1.00
#
# [9 rows x 25 columns]
# ✓ Bam Adebayo récupéré
# % de joueurs sélectionnés : 0.18 %
#  Taille de l'échantillon : 5135
#       Player SEASON_ID   PPG  RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Deng Adel   2018-19  1.68  1.0  0.26  0.21  0.05               CLE
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT     Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        22.0  19  ...    4     1.0  Deng Adel   0.32   0.7    0.32    1.21
#
#   FGMPG  FGAPG  OREBPG
# 0  0.58   1.89    0.16
#
# [1 rows x 25 columns]
# ✓ Deng Adel récupéré
# % de joueurs sélectionnés : 0.19 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.19 %
#  Taille de l'échantillon : 5135
#         Player SEASON_ID    PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Jeff Adrien   2010-11   2.48  2.52  0.43  0.22  0.17               GSW
# 1  Jeff Adrien   2011-12   2.62  2.75  0.12  0.25  0.00               HOU
# 2  Jeff Adrien   2012-13   4.02  3.77  0.69  0.52  0.35               CHA
# 3  Jeff Adrien   2013-14   2.28  3.52  0.28  0.60  0.28               CHA
# 4  Jeff Adrien   2013-14  10.89  7.79  1.11  0.75  0.61               MIL
# 5  Jeff Adrien   2013-14   6.83  5.77  0.72  0.68  0.45               TOT
# 6  Jeff Adrien   2014-15   3.53  4.53  0.88  0.53  0.24               MIN
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT       Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        25.0  23  ...   19   0.579  Jeff Adrien   0.39   1.2     0.0    0.00
# 1        26.0   8  ...   12   0.583  Jeff Adrien   0.25   1.6     0.0    0.00
# 2        27.0  52  ...  100   0.650  Jeff Adrien   0.62   1.5     0.0    0.04
# 3        28.0  25  ...   25   0.520  Jeff Adrien   0.32   1.4     0.0    0.00
# 4        28.0  28  ...   94   0.670  Jeff Adrien   1.11   2.6     0.0    0.00
# 5        28.0  53  ...  119   0.639  Jeff Adrien   0.74   2.0     0.0    0.00
# 6        29.0  17  ...   38   0.579  Jeff Adrien   0.53   1.8     0.0    0.00
#
#   FGMPG  FGAPG  OREBPG
# 0  1.00   2.35    1.00
# 1  0.88   2.00    0.62
# 2  1.38   3.23    1.31
# 3  0.88   1.60    1.32
# 4  4.32   8.39    2.46
# 5  2.70   5.19    1.92
# 6  1.12   2.59    1.35
#
# [7 rows x 25 columns]
# ✓ Jeff Adrien récupéré
# % de joueurs sélectionnés : 0.21 %
#  Taille de l'échantillon : 5135
#            Player SEASON_ID    PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0   Arron Afflalo   2007-08   3.68  1.83  0.69  0.11  0.41               DET
# 1   Arron Afflalo   2008-09   4.91  1.81  0.59  0.18  0.38               DET
# 2   Arron Afflalo   2009-10   8.83  3.07  1.68  0.37  0.56               DEN
# 3   Arron Afflalo   2010-11  12.57  3.64  2.43  0.45  0.49               DEN
# 4   Arron Afflalo   2011-12  15.21  3.18  2.40  0.21  0.58               DEN
# 5   Arron Afflalo   2012-13  16.52  3.73  3.22  0.17  0.62               ORL
# 6   Arron Afflalo   2013-14  18.22  3.59  3.40  0.04  0.48               ORL
# 7   Arron Afflalo   2014-15  14.55  3.40  1.91  0.09  0.60               DEN
# 8   Arron Afflalo   2014-15  10.56  2.68  1.12  0.08  0.36               POR
# 9   Arron Afflalo   2014-15  13.27  3.17  1.65  0.09  0.53               TOT
# 10  Arron Afflalo   2015-16  12.80  3.75  2.03  0.14  0.35               NYK
# 11  Arron Afflalo   2016-17   8.44  2.05  1.28  0.10  0.34               SAC
# 12  Arron Afflalo   2017-18   3.38  1.25  0.57  0.17  0.08               ORL
#
#     PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0         22.0  75  ...   87   0.782  Arron Afflalo   0.45   1.1    0.13
# 1         23.0  74  ...   71   0.817  Arron Afflalo   0.58   1.9    0.58
# 2         24.0  82  ...   98   0.735  Arron Afflalo   0.90   2.7    1.32
# 3         25.0  69  ...  163   0.847  Arron Afflalo   1.03   2.2    1.52
# 4         26.0  62  ...  247   0.798  Arron Afflalo   1.37   2.2    1.42
# 5         27.0  64  ...  223   0.857  Arron Afflalo   2.16   2.1    1.12
# 6         28.0  73  ...  336   0.815  Arron Afflalo   2.00   1.9    1.75
# 7         29.0  53  ...  151   0.841  Arron Afflalo   1.57   2.0    1.55
# 8         29.0  25  ...   47   0.851  Arron Afflalo   1.32   2.4    1.44
# 9         29.0  78  ...  198   0.843  Arron Afflalo   1.49   2.1    1.51
# 10        30.0  71  ...  131   0.840  Arron Afflalo   1.15   2.0    1.28
# 11        31.0  61  ...   93   0.892  Arron Afflalo   0.69   1.7    1.02
# 12        32.0  53  ...   26   0.846  Arron Afflalo   0.40   1.1    0.51
#
#     FG3APG FGMPG  FGAPG  OREBPG
# 0     0.64  1.32   3.21    0.48
# 1     1.45  1.77   4.05    0.41
# 2     3.04  3.32   7.13    0.72
# 3     3.59  4.52   9.09    0.65
# 4     3.56  5.31  11.27    0.65
# 5     3.75  6.20  14.14    0.45
# 6     4.11  6.36  13.85    0.44
# 7     4.58  5.30  12.40    0.40
# 8     3.60  3.76   9.08    0.24
# 9     4.27  4.81  11.33    0.35
# 10    3.35  4.99  11.25    0.32
# 11    2.48  3.03   6.89    0.15
# 12    1.32  1.23   3.06    0.08
#
# [13 rows x 25 columns]
# ✓ Arron Afflalo récupéré
# % de joueurs sélectionnés : 0.23 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID    PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Ochai Agbaji   2022-23   7.92  2.05  1.14  0.25  0.27               UTA
# 1  Ochai Agbaji   2023-24   5.37  2.47  0.92  0.57  0.53               UTA
# 2  Ochai Agbaji   2023-24   6.70  3.33  1.33  0.56  0.74               TOR
# 3  Ochai Agbaji   2023-24   5.83  2.77  1.06  0.56  0.60               TOT
# 4  Ochai Agbaji   2024-25  10.42  3.78  1.53  0.47  0.91               TOR
# 5  Ochai Agbaji   2025-26   2.67  2.11  0.67  0.11  0.56               TOR
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  59  ...   69   0.812  Ochai Agbaji   0.69   1.7    1.37
# 1        24.0  51  ...   20   0.750  Ochai Agbaji   0.67   1.3    0.92
# 2        24.0  27  ...   36   0.611  Ochai Agbaji   1.11   1.9    0.56
# 3        24.0  78  ...   56   0.661  Ochai Agbaji   0.82   1.5    0.79
# 4        25.0  64  ...   48   0.708  Ochai Agbaji   0.84   2.0    1.58
# 5        25.0   9  ...    8   0.625  Ochai Agbaji   0.33   1.8    0.11
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    3.86  2.80   6.54    0.73
# 1    2.78  2.08   4.88    0.69
# 2    2.56  2.67   6.81    1.44
# 3    2.71  2.28   5.55    0.95
# 4    3.95  4.16   8.34    0.95
# 5    1.33  1.00   2.78    0.22
#
# [6 rows x 25 columns]
# ✓ Ochai Agbaji récupéré
# % de joueurs sélectionnés : 0.25 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Maurice Ager   2006-07  2.16  0.66  0.22  0.09  0.12               DAL
# 1  Maurice Ager   2007-08  1.25  0.33  0.33  0.08  0.00               DAL
# 2  Maurice Ager   2007-08  2.57  0.64  0.29  0.00  0.00               NJN
# 3  Maurice Ager   2007-08  1.96  0.50  0.31  0.04  0.00               TOT
# 4  Maurice Ager   2008-09  1.70  0.50  0.15  0.10  0.05               NJN
# 5  Maurice Ager   2010-11  3.75  0.50  0.25  0.00  0.25               MIN
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  32  ...   33   0.606  Maurice Ager   0.47   0.8    0.16
# 1        24.0  12  ...    6   0.833  Maurice Ager   0.25   0.9    0.00
# 2        24.0  14  ...    6   0.167  Maurice Ager   0.21   0.4    0.21
# 3        24.0  26  ...   12   0.500  Maurice Ager   0.23   0.7    0.12
# 4        25.0  20  ...    8   0.500  Maurice Ager   0.20   0.8    0.00
# 5        27.0   4  ...    0   0.000  Maurice Ager   1.00   1.0    0.75
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.47  0.69   2.19    0.03
# 1    0.67  0.42   2.25    0.08
# 2    0.79  1.14   2.71    0.21
# 3    0.73  0.81   2.50    0.15
# 4    0.30  0.75   2.15    0.15
# 5    1.00  1.50   2.75    0.00
#
# [6 rows x 25 columns]
# ✓ Maurice Ager récupéré
# % de joueurs sélectionnés : 0.27 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.27 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG  BPG   SPG TEAM_ABBREVIATION  \
# 0  Blake Ahearn   2007-08  5.83  1.58  1.58  0.0  0.50               MIA
# 1  Blake Ahearn   2008-09  2.67  0.33  0.67  0.0  0.33               SAS
# 2  Blake Ahearn   2011-12  2.50  0.50  0.25  0.0  0.00               UTA
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        24.0  12  ...   31   0.968  Blake Ahearn   1.33   1.7    0.83
# 1        25.0   3  ...    2   1.000  Blake Ahearn   0.33   1.0    0.67
# 2        28.0   4  ...    0   0.000  Blake Ahearn   1.25   1.0    0.50
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    2.83  1.25   4.75    0.08
# 1    1.33  0.67   2.00    0.00
# 2    2.25  1.00   3.50    0.00
#
# [3 rows x 25 columns]
# ✓ Blake Ahearn récupéré
# % de joueurs sélectionnés : 0.29 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.29 %
#  Taille de l'échantillon : 5135
#           Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Alexis Ajinca   2008-09  2.26  0.97  0.10  0.19  0.23               CHA
# 1  Alexis Ajinca   2009-10  1.67  0.67  0.00  0.17  0.17               CHA
# 2  Alexis Ajinca   2010-11  2.90  1.70  0.20  0.50  0.30               DAL
# 3  Alexis Ajinca   2010-11  4.75  2.54  0.33  0.58  0.33               TOR
# 4  Alexis Ajinca   2010-11  4.21  2.29  0.29  0.56  0.32               TOT
# 5  Alexis Ajinca   2013-14  5.86  4.95  0.71  0.82  0.41               NOP
# 6  Alexis Ajinca   2014-15  6.51  4.63  0.69  0.75  0.31               NOP
# 7  Alexis Ajinca   2015-16  5.97  4.56  0.53  0.61  0.32               NOP
# 8  Alexis Ajinca   2016-17  5.31  4.54  0.31  0.56  0.51               NOP
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0        21.0  31  ...   28   0.714  Alexis Ajinca   0.39   1.1    0.00
# 1        22.0   6  ...    1   0.000  Alexis Ajinca   0.33   0.8    0.00
# 2        23.0  10  ...    3   0.667  Alexis Ajinca   0.10   1.3    0.30
# 3        23.0  24  ...   15   0.733  Alexis Ajinca   0.71   2.5    0.38
# 4        23.0  34  ...   18   0.722  Alexis Ajinca   0.53   2.1    0.35
# 5        26.0  56  ...   67   0.836  Alexis Ajinca   1.12   3.3    0.00
# 6        27.0  68  ...   99   0.818  Alexis Ajinca   1.01   2.2    0.00
# 7        28.0  59  ...   62   0.839  Alexis Ajinca   0.92   2.3    0.00
# 8        29.0  39  ...   40   0.725  Alexis Ajinca   0.79   2.0    0.00
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.06  0.81   2.23    0.29
# 1    0.00  0.83   1.67    0.17
# 2    0.70  1.20   3.20    0.50
# 3    1.12  1.96   4.21    0.50
# 4    1.00  1.74   3.91    0.50
# 5    0.02  2.43   4.45    1.68
# 6    0.00  2.66   4.84    1.53
# 7    0.02  2.54   5.34    1.27
# 8    0.10  2.28   4.56    1.18
#
# [9 rows x 25 columns]
# ✓ Alexis Ajinca récupéré
# % de joueurs sélectionnés : 0.31 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.31 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG  BPG  SPG TEAM_ABBREVIATION  \
# 0  Josh Akognon   2012-13  1.67  0.33  0.33  0.0  0.0               DAL
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        27.0   3  ...    0     0.0  Josh Akognon    0.0   1.0    0.33
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.67  0.67   1.33     0.0
#
# [1 rows x 25 columns]
# ✓ Josh Akognon récupéré
# % de joueurs sélectionnés : 0.33 %
#  Taille de l'échantillon : 5135
# ✗ Erreur pour DeVaughn Akoon-Purcell: 'resultSet'
#           Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Solomon Alabi   2010-11  0.50  1.17  0.17  0.17  0.17               TOR
# 1  Solomon Alabi   2011-12  2.36  3.36  0.21  0.64  0.14               TOR
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  12  ...    2   0.000  Solomon Alabi   0.25   0.4     0.0
# 1        24.0  14  ...    8   0.875  Solomon Alabi   0.36   0.8     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.0  0.25   1.25    0.58
# 1     0.0  0.93   2.57    1.07
#
# [2 rows x 25 columns]
# ✓ Solomon Alabi récupéré
# % de joueurs sélectionnés : 0.35 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.35 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.35 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID    PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Santi Aldama   2021-22   4.12  2.72  0.66  0.31  0.19               MEM
# 1  Santi Aldama   2022-23   9.04  4.82  1.26  0.62  0.58               MEM
# 2  Santi Aldama   2023-24  10.72  5.77  2.26  0.89  0.70               MEM
# 3  Santi Aldama   2024-25  12.48  6.40  2.89  0.45  0.80               MEM
# 4  Santi Aldama   2025-26  12.64  6.86  2.50  0.57  1.07               MEM
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        21.0  32  ...   32   0.625  Santi Aldama   0.50   1.1    0.19
# 1        22.0  77  ...  144   0.750  Santi Aldama   0.78   1.9    1.22
# 2        23.0  61  ...   87   0.621  Santi Aldama   1.13   1.5    1.74
# 3        24.0  65  ...   94   0.691  Santi Aldama   1.09   1.2    1.85
# 4        24.0  14  ...   33   0.576  Santi Aldama   1.29   1.6    1.43
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    1.50  1.66   4.12    1.03
# 1    3.45  3.21   6.82    1.10
# 2    4.98  4.05   9.31    1.18
# 3    5.02  4.82   9.97    1.45
# 4    4.57  4.93  10.64    1.57
#
# [5 rows x 25 columns]
# ✓ Santi Aldama récupéré
# % de joueurs sélectionnés : 0.37 %
#  Taille de l'échantillon : 5135
#            Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Furkan Aldemir   2014-15  2.27  4.29  0.68  0.39  0.41               PHI
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT          Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  41  ...   27   0.481  Furkan Aldemir   0.41   2.3     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.12  0.98    1.9     1.9
#
# [1 rows x 25 columns]
# ✓ Furkan Aldemir récupéré
# % de joueurs sélectionnés : 0.39 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Cole Aldrich   2010-11  1.00  1.94  0.22  0.39  0.28               OKC
# 1  Cole Aldrich   2011-12  2.19  1.85  0.12  0.62  0.31               OKC
# 2  Cole Aldrich   2012-13  1.67  1.90  0.20  0.30  0.10               HOU
# 3  Cole Aldrich   2012-13  3.33  4.20  0.20  0.93  0.13               SAC
# 4  Cole Aldrich   2012-13  2.22  2.67  0.20  0.51  0.11               TOT
# 5  Cole Aldrich   2013-14  2.00  2.80  0.30  0.65  0.17               NYK
# 6  Cole Aldrich   2014-15  5.54  5.54  1.23  1.07  0.61               NYK
# 7  Cole Aldrich   2015-16  5.47  4.80  0.83  1.13  0.78               LAC
# 8  Cole Aldrich   2016-17  1.69  2.55  0.40  0.37  0.40               MIN
# 9  Cole Aldrich   2017-18  0.57  0.71  0.14  0.05  0.10               MIN
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        22.0  18  ...    4   0.500  Cole Aldrich   0.44   1.7     0.0
# 1        23.0  26  ...   14   0.929  Cole Aldrich   0.35   0.8     0.0
# 2        24.0  30  ...    9   0.444  Cole Aldrich   0.47   1.4     0.0
# 3        24.0  15  ...   11   0.727  Cole Aldrich   0.60   1.3     0.0
# 4        24.0  45  ...   20   0.600  Cole Aldrich   0.51   1.3     0.0
# 5        25.0  46  ...   30   0.867  Cole Aldrich   0.39   0.9     0.0
# 6        26.0  61  ...   64   0.781  Cole Aldrich   0.97   2.0     0.0
# 7        27.0  60  ...   84   0.714  Cole Aldrich   1.07   2.3     0.0
# 8        28.0  62  ...   22   0.682  Cole Aldrich   0.27   1.4     0.0
# 9        29.0  21  ...    6   0.333  Cole Aldrich   0.05   0.5     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.0  0.44   0.83    0.72
# 1     0.0  0.85   1.62    0.50
# 2     0.0  0.77   1.43    0.40
# 3     0.0  1.40   2.47    1.20
# 4     0.0  0.98   1.78    0.67
# 5     0.0  0.72   1.33    0.80
# 6     0.0  2.36   4.93    1.66
# 7     0.0  2.23   3.75    1.43
# 8     0.0  0.73   1.39    0.82
# 9     0.0  0.24   0.71    0.14
#
# [10 rows x 25 columns]
# ✓ Cole Aldrich récupéré
# % de joueurs sélectionnés : 0.41 %
#  Taille de l'échantillon : 5135
#                Player SEASON_ID    PPG    RPG   APG   BPG   SPG  \
# 0   LaMarcus Aldridge   2006-07   8.97   4.95  0.38  1.16  0.35
# 1   LaMarcus Aldridge   2007-08  17.76   7.61  1.61  1.24  0.72
# 2   LaMarcus Aldridge   2008-09  18.15   7.47  1.94  0.95  0.95
# 3   LaMarcus Aldridge   2009-10  17.86   8.04  2.05  0.62  0.86
# 4   LaMarcus Aldridge   2010-11  21.84   8.75  2.10  1.16  1.01
# 5   LaMarcus Aldridge   2011-12  21.65   8.04  2.44  0.82  0.93
# 6   LaMarcus Aldridge   2012-13  21.08   9.05  2.59  1.23  0.84
# 7   LaMarcus Aldridge   2013-14  23.23  11.09  2.58  0.99  0.91
# 8   LaMarcus Aldridge   2014-15  23.39  10.23  1.75  0.96  0.68
# 9   LaMarcus Aldridge   2015-16  17.99   8.54  1.49  1.09  0.51
# 10  LaMarcus Aldridge   2016-17  17.26   7.26  1.93  1.22  0.64
# 11  LaMarcus Aldridge   2017-18  23.13   8.47  2.03  1.20  0.57
# 12  LaMarcus Aldridge   2018-19  21.32   9.19  2.40  1.32  0.53
# 13  LaMarcus Aldridge   2019-20  18.89   7.40  2.43  1.64  0.68
# 14  LaMarcus Aldridge   2020-21  13.71   4.48  1.71  0.86  0.38
# 15  LaMarcus Aldridge   2020-21  12.80   4.80  2.60  2.20  0.60
# 16  LaMarcus Aldridge   2020-21  13.54   4.54  1.88  1.12  0.42
# 17  LaMarcus Aldridge   2021-22  12.91   5.49  0.89  1.00  0.30
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP  ...  FTA  FT_PCT             Player  \
# 0                POR        21.0  63  ...  115   0.722  LaMarcus Aldridge
# 1                POR        22.0  76  ...  298   0.762  LaMarcus Aldridge
# 2                POR        23.0  81  ...  334   0.781  LaMarcus Aldridge
# 3                POR        24.0  78  ...  304   0.757  LaMarcus Aldridge
# 4                POR        25.0  81  ...  444   0.791  LaMarcus Aldridge
# 5                POR        26.0  55  ...  274   0.814  LaMarcus Aldridge
# 6                POR        27.0  74  ...  348   0.810  LaMarcus Aldridge
# 7                POR        28.0  69  ...  360   0.822  LaMarcus Aldridge
# 8                POR        29.0  71  ...  362   0.845  LaMarcus Aldridge
# 9                SAS        30.0  74  ...  302   0.858  LaMarcus Aldridge
# 10               SAS        31.0  72  ...  271   0.812  LaMarcus Aldridge
# 11               SAS        32.0  75  ...  399   0.837  LaMarcus Aldridge
# 12               SAS        33.0  81  ...  412   0.847  LaMarcus Aldridge
# 13               SAS        34.0  53  ...  191   0.827  LaMarcus Aldridge
# 14               SAS        35.0  21  ...   37   0.838  LaMarcus Aldridge
# 15               BKN        35.0   5  ...   10   1.000  LaMarcus Aldridge
# 16               TOT        35.0  26  ...   47   0.872  LaMarcus Aldridge
# 17               BKN        36.0  47  ...  102   0.873  LaMarcus Aldridge
#
#     TOVPG  PFPG  FG3MPG  FG3APG FGMPG  FGAPG  OREBPG
# 0    0.68   3.0    0.00    0.03  3.83   7.60    2.29
# 1    1.66   3.2    0.01    0.09  7.38  15.26    2.89
# 2    1.49   2.6    0.09    0.35  7.42  15.35    2.89
# 3    1.33   3.0    0.06    0.21  7.42  14.99    2.46
# 4    1.89   2.7    0.05    0.28  8.73  17.47    3.43
# 5    2.02   2.8    0.04    0.20  8.78  17.15    2.73
# 6    1.93   2.5    0.03    0.19  8.62  17.81    2.36
# 7    1.78   2.1    0.04    0.22  9.45  20.62    2.41
# 8    1.72   1.8    0.52    1.48  9.28  19.93    2.49
# 9    1.34   2.0    0.00    0.22  7.24  14.12    2.38
# 10   1.36   2.2    0.32    0.78  6.94  14.57    2.39
# 11   1.48   2.1    0.36    1.23  9.16  17.96    3.28
# 12   1.78   2.2    0.12    0.52  8.44  16.28    3.10
# 13   1.40   2.4    1.15    2.96  7.38  14.96    1.94
# 14   0.95   1.7    1.29    3.57  5.48  11.81    0.81
# 15   1.40   2.2    0.80    1.00  5.00   9.60    0.40
# 16   1.04   1.8    1.19    3.08  5.38  11.38    0.73
# 17   0.94   1.7    0.30    0.98  5.36   9.74    1.55
#
# [18 rows x 25 columns]
# ✓ LaMarcus Aldridge récupéré
# % de joueurs sélectionnés : 0.43 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.43 %
#  Taille de l'échantillon : 5135
#             Player SEASON_ID   PPG   RPG  APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Cliff Alexander   2015-16  1.25  0.75  0.0  0.25  0.12               POR
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT           Player  TOVPG  PFPG  FG3MPG  \
# 0        20.0   8  ...    0     0.0  Cliff Alexander   0.12   0.1     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.0  0.62   1.25    0.25
#
# [1 rows x 25 columns]
# ✓ Cliff Alexander récupéré
# % de joueurs sélectionnés : 0.45 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.45 %
#  Taille de l'échantillon : 5135
#                Player SEASON_ID    PPG   RPG   APG   BPG   SPG  \
# 0  Courtney Alexander   2000-01   4.21  1.66  0.55  0.08  0.42
# 1  Courtney Alexander   2000-01  16.96  2.96  1.52  0.07  1.07
# 2  Courtney Alexander   2000-01   9.51  2.20  0.95  0.08  0.69
# 3  Courtney Alexander   2001-02   9.80  2.64  1.54  0.12  0.62
# 4  Courtney Alexander   2002-03   7.92  1.79  1.20  0.09  0.47
#
#   TEAM_ABBREVIATION  PLAYER_AGE  GP  ...  FTA  FT_PCT              Player  \
# 0               DAL        24.0  38  ...   45   0.733  Courtney Alexander
# 1               WAS        24.0  27  ...  105   0.857  Courtney Alexander
# 2               TOT        24.0  65  ...  150   0.820  Courtney Alexander
# 3               WAS        25.0  56  ...  121   0.810  Courtney Alexander
# 4               NOH        26.0  66  ...  146   0.808  Courtney Alexander
#
#    TOVPG  PFPG  FG3MPG  FG3APG FGMPG  FGAPG  OREBPG
# 0   0.55   2.0    0.08    0.26  1.63   4.68    0.53
# 1   2.00   2.3    0.52    1.33  6.56  14.63    0.81
# 2   1.15   2.1    0.26    0.71  3.68   8.82    0.65
# 3   1.07   2.0    0.09    0.32  3.98   8.46    0.77
# 4   1.03   1.9    0.29    0.86  2.92   7.65    0.59
#
# [5 rows x 25 columns]
# ✓ Courtney Alexander récupéré
# % de joueurs sélectionnés : 0.47 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.47 %
#  Taille de l'échantillon : 5135
#           Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Joe Alexander   2008-09  4.71  1.95  0.71  0.49  0.25               MIL
# 1  Joe Alexander   2009-10  0.50  0.62  0.25  0.12  0.12               CHI
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0        22.0  59  ...   83   0.699  Joe Alexander   0.88   1.8    0.27
# 1        23.0   8  ...    3   0.667  Joe Alexander   0.00   1.1    0.00
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.78  1.73   4.15    0.75
# 1    0.12  0.12   0.75    0.25
#
# [2 rows x 25 columns]
# ✓ Joe Alexander récupéré
# % de joueurs sélectionnés : 0.49 %
#  Taille de l'échantillon : 5135
#            Player SEASON_ID  PPG  RPG  APG  BPG  SPG TEAM_ABBREVIATION  \
# 0  Kyle Alexander   2019-20  1.0  1.5  0.0  0.0  0.0               MIA
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT          Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0   2  ...    0     0.0  Kyle Alexander    0.5   0.5     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.0   0.5    1.0     1.0
#
# [1 rows x 25 columns]
# ✓ Kyle Alexander récupéré
# % de joueurs sélectionnés : 0.51 %
#  Taille de l'échantillon : 5135
#            Player SEASON_ID   PPG  RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Trey Alexander   2024-25  1.33  0.5  0.46  0.04  0.08               DEN
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT          Player  TOVPG  PFPG  FG3MPG  \
# 0        22.0  24  ...    4    0.75  Trey Alexander   0.21   0.4    0.12
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.71  0.54   1.71    0.04
#
# [1 rows x 25 columns]
# ✓ Trey Alexander récupéré
# % de joueurs sélectionnés : 0.53 %
#  Taille de l'échantillon : 5135
#               Player SEASON_ID  PPG   RPG  APG   BPG  SPG TEAM_ABBREVIATION  \
# 0  Ty-Shon Alexander   2020-21  0.6  0.67  0.4  0.07  0.0               PHX
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT             Player  TOVPG  PFPG  FG3MPG  \
# 0        22.0  15  ...    2     0.5  Ty-Shon Alexander    0.2   0.1    0.13
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.6   0.2    0.8    0.13
#
# [1 rows x 25 columns]
# ✓ Ty-Shon Alexander récupéré
# % de joueurs sélectionnés : 0.55 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.55 %
#  Taille de l'échantillon : 5135
#                       Player SEASON_ID    PPG   RPG   APG   BPG   SPG  \
# 0   Nickeil Alexander-Walker   2019-20   5.68  1.79  1.89  0.17  0.36
# 1   Nickeil Alexander-Walker   2020-21  11.04  3.13  2.22  0.48  1.02
# 2   Nickeil Alexander-Walker   2021-22  12.78  3.28  2.78  0.38  0.82
# 3   Nickeil Alexander-Walker   2021-22   3.53  1.53  1.13  0.27  0.33
# 4   Nickeil Alexander-Walker   2021-22  10.65  2.88  2.40  0.35  0.71
# 5   Nickeil Alexander-Walker   2022-23   6.33  1.64  2.11  0.39  0.67
# 6   Nickeil Alexander-Walker   2022-23   5.87  1.83  1.39  0.30  0.35
# 7   Nickeil Alexander-Walker   2022-23   6.15  1.71  1.83  0.36  0.54
# 8   Nickeil Alexander-Walker   2023-24   7.99  2.04  2.49  0.51  0.78
# 9   Nickeil Alexander-Walker   2024-25   9.43  3.23  2.72  0.41  0.61
# 10  Nickeil Alexander-Walker   2025-26  17.09  2.82  3.45  1.00  1.00
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP  ...  FTA  FT_PCT  \
# 0                NOP        21.0  47  ...   37   0.676
# 1                NOP        22.0  46  ...   66   0.727
# 2                NOP        23.0  50  ...   97   0.722
# 3                UTA        23.0  15  ...   12   0.917
# 4                TOT        23.0  65  ...  109   0.743
# 5                UTA        24.0  36  ...   39   0.692
# 6                MIN        24.0  23  ...   21   0.619
# 7                TOT        24.0  59  ...   60   0.667
# 8                MIN        25.0  82  ...   65   0.800
# 9                MIN        26.0  82  ...  118   0.780
# 10               ATL        27.0  11  ...   51   0.863
#
#                       Player  TOVPG  PFPG  FG3MPG  FG3APG FGMPG  FGAPG  OREBPG
# 0   Nickeil Alexander-Walker   1.15   1.2    0.98    2.83  2.09   5.66    0.19
# 1   Nickeil Alexander-Walker   1.50   1.9    1.65    4.76  4.17   9.96    0.28
# 2   Nickeil Alexander-Walker   1.70   1.8    1.90    6.10  4.74  12.64    0.72
# 3   Nickeil Alexander-Walker   0.53   1.0    0.67    2.20  1.07   3.20    0.07
# 4   Nickeil Alexander-Walker   1.43   1.6    1.62    5.20  3.89  10.46    0.57
# 5   Nickeil Alexander-Walker   1.25   1.6    0.97    2.42  2.31   4.72    0.22
# 6   Nickeil Alexander-Walker   0.43   1.3    1.13    3.13  2.09   5.43    0.30
# 7   Nickeil Alexander-Walker   0.93   1.5    1.03    2.69  2.22   5.00    0.25
# 8   Nickeil Alexander-Walker   0.93   1.7    1.60    4.09  2.88   6.56    0.43
# 9   Nickeil Alexander-Walker   1.21   1.7    1.72    4.51  3.29   7.51    0.66
# 10  Nickeil Alexander-Walker   2.64   1.6    1.82    5.64  5.64  13.00    0.64
#
# [11 rows x 25 columns]
# ✓ Nickeil Alexander-Walker récupéré
# % de joueurs sélectionnés : 0.56 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.56 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID  PPG  RPG  APG  BPG  SPG TEAM_ABBREVIATION  \
# 0  Rawle Alkins   2018-19  3.7  2.6  1.3  0.0  0.1               CHI
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        21.0  10  ...   12   0.667  Rawle Alkins    0.8   0.7     0.3
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     1.2   1.3    3.9     1.1
#
# [1 rows x 25 columns]
# ✓ Rawle Alkins récupéré
# % de joueurs sélectionnés : 0.58 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.58 %
#  Taille de l'échantillon : 5135
#           Player SEASON_ID    PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Grayson Allen   2018-19   5.55  0.61  0.66  0.16  0.16               UTA
# 1  Grayson Allen   2019-20   8.68  2.24  1.37  0.05  0.26               MEM
# 2  Grayson Allen   2020-21  10.64  3.20  2.16  0.16  0.92               MEM
# 3  Grayson Allen   2021-22  11.11  3.36  1.52  0.27  0.70               MIL
# 4  Grayson Allen   2022-23  10.42  3.29  2.26  0.19  0.86               MIL
# 5  Grayson Allen   2023-24  13.52  3.93  3.03  0.60  0.92               PHX
# 6  Grayson Allen   2024-25  10.62  3.03  2.14  0.30  0.84               PHX
# 7  Grayson Allen   2025-26  18.46  3.08  4.31  0.31  1.62               PHX
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  38  ...   60   0.750  Grayson Allen   0.87   1.2    0.84
# 1        24.0  38  ...   45   0.867  Grayson Allen   0.87   1.4    1.50
# 2        25.0  50  ...   91   0.868  Grayson Allen   0.96   1.4    2.14
# 3        26.0  66  ...   74   0.865  Grayson Allen   0.65   1.5    2.41
# 4        27.0  72  ...  126   0.905  Grayson Allen   1.00   1.6    2.03
# 5        28.0  75  ...  147   0.878  Grayson Allen   1.27   2.1    2.73
# 6        29.0  64  ...  114   0.816  Grayson Allen   1.17   1.5    2.33
# 7        30.0  13  ...   34   0.794  Grayson Allen   1.77   2.3    3.92
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    2.61  1.76   4.68    0.08
# 1    3.71  3.08   6.61    0.21
# 2    5.48  3.46   8.28    0.38
# 3    5.89  3.86   8.62    0.48
# 4    5.08  3.40   7.74    0.85
# 5    5.93  4.53   9.09    0.64
# 6    5.47  3.42   7.64    0.53
# 7    8.77  6.23  13.31    0.46
#
# [8 rows x 25 columns]
# ✓ Grayson Allen récupéré
# % de joueurs sélectionnés : 0.60 %
#  Taille de l'échantillon : 5135
#            Player SEASON_ID    PPG    RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0   Jarrett Allen   2017-18   8.15   5.39  0.68  1.22  0.39               BKN
# 1   Jarrett Allen   2018-19  10.91   8.40  1.38  1.50  0.54               BKN
# 2   Jarrett Allen   2019-20  11.07   9.59  1.57  1.31  0.57               BKN
# 3   Jarrett Allen   2020-21  11.17  10.42  1.67  1.58  0.58               BKN
# 4   Jarrett Allen   2020-21  13.18   9.92  1.69  1.39  0.49               CLE
# 5   Jarrett Allen   2020-21  12.79  10.02  1.68  1.43  0.51               TOT
# 6   Jarrett Allen   2021-22  16.14  10.75  1.64  1.34  0.79               CLE
# 7   Jarrett Allen   2022-23  14.25   9.79  1.66  1.24  0.79               CLE
# 8   Jarrett Allen   2023-24  16.51  10.53  2.73  1.05  0.69               CLE
# 9   Jarrett Allen   2024-25  13.45   9.73  1.93  0.89  0.94               CLE
# 10  Jarrett Allen   2025-26  15.58   7.75  1.75  0.92  1.17               CLE
#
#     PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0         20.0  72  ...  147   0.776  Jarrett Allen   1.14   2.0    0.07
# 1         21.0  80  ...  278   0.709  Jarrett Allen   1.29   2.3    0.08
# 2         22.0  70  ...  270   0.633  Jarrett Allen   1.10   2.3    0.00
# 3         23.0  12  ...   61   0.754  Jarrett Allen   1.83   1.8    0.00
# 4         23.0  51  ...  229   0.690  Jarrett Allen   1.53   1.5    0.12
# 5         23.0  63  ...  290   0.703  Jarrett Allen   1.59   1.5    0.10
# 6         24.0  56  ...  233   0.708  Jarrett Allen   1.68   1.7    0.02
# 7         25.0  68  ...  221   0.733  Jarrett Allen   1.37   2.2    0.01
# 8         26.0  77  ...  314   0.742  Jarrett Allen   1.57   1.9    0.00
# 9         27.0  82  ...  277   0.718  Jarrett Allen   1.18   1.5    0.00
# 10        27.0  12  ...   60   0.750  Jarrett Allen   1.58   1.5    0.00
#
#     FG3APG FGMPG  FGAPG  OREBPG
# 0     0.21  3.25   5.51    2.00
# 1     0.56  4.19   7.10    2.39
# 2     0.09  4.31   6.64    3.09
# 3     0.00  3.67   5.42    3.17
# 4     0.37  4.98   8.18    3.10
# 5     0.30  4.73   7.65    3.11
# 6     0.18  6.59   9.73    3.43
# 7     0.15  5.93   9.21    3.25
# 8     0.08  6.74  10.64    3.16
# 9     0.06  5.51   7.80    2.63
# 10    0.33  5.92  10.08    2.42
#
# [11 rows x 25 columns]
# ✓ Jarrett Allen récupéré
# % de joueurs sélectionnés : 0.62 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 0.62 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Kadeem Allen   2017-18  1.06  0.61  0.67  0.11  0.17               BOS
# 1  Kadeem Allen   2018-19  9.95  2.68  4.00  0.21  0.84               NYK
# 2  Kadeem Allen   2019-20  5.00  0.90  2.10  0.20  0.50               NYK
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        25.0  18  ...    9   0.778  Kadeem Allen   0.50   0.8    0.00
# 1        26.0  19  ...   54   0.778  Kadeem Allen   1.37   2.4    0.89
# 2        27.0  10  ...   11   0.636  Kadeem Allen   0.80   0.7    0.50
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.61  0.33   1.22    0.22
# 1    1.89  3.42   7.42    0.42
# 2    1.60  1.90   4.40    0.20
#
# [3 rows x 25 columns]
# ✓ Kadeem Allen récupéré
# % de joueurs sélectionnés : 0.64 %
#  Taille de l'échantillon : 5135
#         Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Lavoy Allen   2011-12  4.12  4.17  0.83  0.44  0.32               PHI
# 1  Lavoy Allen   2012-13  5.76  5.00  0.92  0.70  0.30               PHI
# 2  Lavoy Allen   2013-14  5.16  5.43  1.27  0.53  0.43               PHI
# 3  Lavoy Allen   2013-14  2.86  2.43  0.43  0.43  0.14               IND
# 4  Lavoy Allen   2013-14  4.66  4.78  1.09  0.51  0.37               TOT
# 5  Lavoy Allen   2014-15  5.00  5.13  1.16  0.67  0.24               IND
# 6  Lavoy Allen   2015-16  5.42  5.37  0.96  0.53  0.33               IND
# 7  Lavoy Allen   2016-17  2.90  3.59  0.93  0.39  0.30               IND
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT       Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        23.0  41  ...   14   0.786  Lavoy Allen   0.49   1.8    0.00    0.00
# 1        24.0  79  ...   60   0.717  Lavoy Allen   0.70   2.3    0.00    0.01
# 2        25.0  51  ...   40   0.675  Lavoy Allen   0.78   2.3    0.04    0.25
# 3        25.0  14  ...   10   0.600  Lavoy Allen   0.29   0.8    0.00    0.00
# 4        25.0  65  ...   50   0.660  Lavoy Allen   0.68   1.9    0.03    0.20
# 5        26.0  63  ...   47   0.702  Lavoy Allen   0.63   1.6    0.00    0.00
# 6        27.0  79  ...   73   0.630  Lavoy Allen   0.87   1.9    0.00    0.00
# 7        28.0  61  ...   33   0.697  Lavoy Allen   0.48   1.3    0.00    0.02
#
#   FGMPG  FGAPG  OREBPG
# 0  1.93   4.07    1.15
# 1  2.61   5.75    2.01
# 2  2.29   5.22    2.08
# 3  1.21   2.43    0.93
# 4  2.06   4.62    1.83
# 5  2.24   4.75    1.95
# 6  2.42   4.68    2.05
# 7  1.26   2.75    1.72
#
# [8 rows x 25 columns]
# ✓ Lavoy Allen récupéré
# % de joueurs sélectionnés : 0.66 %
#  Taille de l'échantillon : 5135
# ...
#  Taille de l'échantillon : 5135
#            Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Udoka Azubuike   2020-21  1.07  0.87  0.00  0.27  0.07               UTA
# 1  Udoka Azubuike   2021-22  4.71  4.18  0.00  0.65  0.06               UTA
# 2  Udoka Azubuike   2022-23  3.47  3.31  0.31  0.42  0.17               UTA
# 3  Udoka Azubuike   2023-24  2.19  2.00  0.19  0.38  0.06               PHX
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT          Player  TOVPG  PFPG  FG3MPG  \
# 0        21.0  15  ...   10   0.800  Udoka Azubuike   0.20   0.6     0.0
# 1        22.0  17  ...   11   0.545  Udoka Azubuike   0.71   1.5     0.0
# 2        23.0  36  ...   20   0.350  Udoka Azubuike   0.50   0.9     0.0
# 3        24.0  16  ...   13   0.231  Udoka Azubuike   0.25   1.1     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.0  0.27   0.60    0.27
# 1     0.0  2.18   2.88    1.06
# 2     0.0  1.64   2.00    0.86
# 3     0.0  1.00   1.44    0.69
#
# [4 rows x 25 columns]
# ✓ Udoka Azubuike récupéré
# % de joueurs sélectionnés : 1.56 %
#  Taille de l'échantillon : 5135
#        Player SEASON_ID   PPG   RPG   APG  BPG   SPG TEAM_ABBREVIATION  \
# 0  Chris Babb   2013-14  1.57  1.21  0.21  0.0  0.43               BOS
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT      Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        24.0  14  ...    0     0.0  Chris Babb   0.21   0.9    0.43    1.93
#
#   FGMPG  FGAPG  OREBPG
# 0  0.57   2.14    0.29
#
# [1 rows x 25 columns]
# ✓ Chris Babb récupéré
# % de joueurs sélectionnés : 1.58 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Luke Babbitt   2010-11  1.50  1.25  0.25  0.08  0.08               POR
# 1  Luke Babbitt   2011-12  5.05  2.38  0.40  0.10  0.25               POR
# 2  Luke Babbitt   2012-13  3.94  2.21  0.47  0.08  0.23               POR
# 3  Luke Babbitt   2013-14  6.30  3.26  1.07  0.41  0.26               NOP
# 4  Luke Babbitt   2014-15  4.06  1.76  0.38  0.17  0.27               NOP
# 5  Luke Babbitt   2015-16  6.96  3.15  1.13  0.15  0.23               NOP
# 6  Luke Babbitt   2016-17  4.76  2.07  0.53  0.16  0.29               MIA
# 7  Luke Babbitt   2017-18  6.11  2.19  0.70  0.14  0.19               ATL
# 8  Luke Babbitt   2017-18  2.54  1.15  0.38  0.15  0.08               MIA
# 9  Luke Babbitt   2017-18  5.18  1.92  0.62  0.14  0.16               TOT
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        22.0  24  ...    9   0.333  Luke Babbitt   0.33   0.6    0.12
# 1        23.0  40  ...   20   0.850  Luke Babbitt   0.68   1.2    1.08
# 2        24.0  62  ...   13   0.769  Luke Babbitt   0.35   1.3    1.00
# 3        25.0  27  ...   18   0.778  Luke Babbitt   0.56   1.9    1.33
# 4        26.0  63  ...   19   0.684  Luke Babbitt   0.41   1.0    0.94
# 5        27.0  47  ...   50   0.780  Luke Babbitt   0.49   1.9    0.94
# 6        28.0  68  ...   15   0.733  Luke Babbitt   0.37   1.7    1.28
# 7        29.0  37  ...   22   0.773  Luke Babbitt   0.41   1.3    1.32
# 8        29.0  13  ...    0   0.000  Luke Babbitt   0.31   0.5    0.85
# 9        29.0  50  ...   22   0.773  Luke Babbitt   0.38   1.1    1.20
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.67  0.62   2.29    0.25
# 1    2.50  1.78   4.32    0.40
# 2    2.87  1.39   3.77    0.24
# 3    3.52  2.22   5.70    0.67
# 4    1.83  1.46   3.05    0.19
# 5    2.32  2.60   6.15    0.53
# 6    3.09  1.66   4.13    0.18
# 7    3.00  2.16   4.54    0.14
# 8    3.46  0.85   3.62    0.15
# 9    3.12  1.82   4.30    0.14
#
# [10 rows x 25 columns]
# ✓ Luke Babbitt récupéré
# % de joueurs sélectionnés : 1.60 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.60 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.60 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID    PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Dwayne Bacon   2017-18   3.30  2.34  0.72  0.04  0.30               CHA
# 1  Dwayne Bacon   2018-19   7.35  2.07  1.09  0.12  0.28               CHA
# 2  Dwayne Bacon   2019-20   5.74  2.56  1.33  0.05  0.59               CHA
# 3  Dwayne Bacon   2020-21  10.94  3.11  1.29  0.07  0.62               ORL
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        22.0  53  ...   25   0.800  Dwayne Bacon   0.43   0.9    0.21
# 1        23.0  43  ...   46   0.739  Dwayne Bacon   0.42   1.7    0.88
# 2        24.0  39  ...   53   0.660  Dwayne Bacon   0.95   1.3    0.49
# 3        25.0  72  ...  176   0.824  Dwayne Bacon   0.64   1.4    0.82
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.81  1.36   3.62    0.08
# 1    2.02  2.84   5.98    0.19
# 2    1.72  2.18   6.26    0.38
# 3    2.88  4.06  10.08    0.43
#
# [4 rows x 25 columns]
# ✓ Dwayne Bacon récupéré
# % de joueurs sélectionnés : 1.62 %
#  Taille de l'échantillon : 5135
#        Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Ibou Badji   2023-24  1.55  2.32  0.59  0.91  0.14               POR
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT      Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        21.0  22  ...   12     0.5  Ibou Badji   0.68   2.1     0.0     0.0
#
#   FGMPG  FGAPG  OREBPG
# 0  0.64    1.0    0.91
#
# [1 rows x 25 columns]
# ✓ Ibou Badji récupéré
# % de joueurs sélectionnés : 1.64 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.64 %
#  Taille de l'échantillon : 5135
#             Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Dalibor Bagaric   2000-01  1.34  1.60  0.29  0.46  0.26               CHI
# 1  Dalibor Bagaric   2001-02  3.70  3.24  0.46  0.48  0.34               CHI
# 2  Dalibor Bagaric   2002-03  1.90  2.00  0.40  0.30  0.30               CHI
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT           Player  TOVPG  PFPG  FG3MPG  \
# 0        20.0  35  ...   28   0.464  Dalibor Bagaric   0.60   1.3     0.0
# 1        21.0  50  ...   70   0.586  Dalibor Bagaric   0.92   2.2     0.0
# 2        22.0  10  ...    4   0.750  Dalibor Bagaric   0.50   1.1     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.03  0.49   1.86    0.63
# 1    0.02  1.44   3.56    1.10
# 2    0.00  0.80   2.60    0.70
#
# [3 rows x 25 columns]
# ✓ Dalibor Bagaric récupéré
# % de joueurs sélectionnés : 1.66 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.66 %
#  Taille de l'échantillon : 5135
#           Player SEASON_ID  PPG  RPG  APG  BPG  SPG TEAM_ABBREVIATION  \
# 0  Marcus Bagley   2024-25  6.7  7.0  1.0  1.2  0.9               PHI
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0        23.0  10  ...   10     0.8  Marcus Bagley    0.7   1.6     0.5
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     3.2   2.7    6.9     2.3
#
# [1 rows x 25 columns]
# ✓ Marcus Bagley récupéré
# % de joueurs sélectionnés : 1.67 %
#  Taille de l'échantillon : 5135
#                Player SEASON_ID    PPG   RPG   APG   BPG   SPG  \
# 0   Marvin Bagley III   2018-19  14.89  7.60  1.00  0.95  0.53
# 1   Marvin Bagley III   2019-20  14.23  7.46  0.77  0.92  0.46
# 2   Marvin Bagley III   2020-21  14.14  7.40  1.00  0.49  0.49
# 3   Marvin Bagley III   2021-22   9.27  7.17  0.57  0.37  0.30
# 4   Marvin Bagley III   2021-22  14.56  6.83  1.06  0.39  0.72
# 5   Marvin Bagley III   2021-22  11.25  7.04  0.75  0.38  0.46
# 6   Marvin Bagley III   2022-23  12.00  6.40  0.86  0.71  0.45
# 7   Marvin Bagley III   2023-24  10.19  4.54  1.04  0.54  0.19
# 8   Marvin Bagley III   2023-24  13.25  8.08  1.17  0.79  0.62
# 9   Marvin Bagley III   2023-24  11.66  6.24  1.10  0.66  0.40
# 10  Marvin Bagley III   2024-25   4.89  2.95  0.37  0.26  0.37
# 11  Marvin Bagley III   2024-25   3.58  2.33  0.33  0.25  0.17
# 12  Marvin Bagley III   2024-25   4.39  2.71  0.35  0.26  0.29
# 13  Marvin Bagley III   2025-26   7.50  4.33  1.25  0.58  0.50
#
#    TEAM_ABBREVIATION  PLAYER_AGE  GP  ...  FTA  FT_PCT             Player  \
# 0                SAC        20.0  62  ...  262   0.691  Marvin Bagley III
# 1                SAC        21.0  13  ...   31   0.806  Marvin Bagley III
# 2                SAC        22.0  43  ...  134   0.575  Marvin Bagley III
# 3                SAC        23.0  30  ...   47   0.745  Marvin Bagley III
# 4                DET        23.0  18  ...   54   0.593  Marvin Bagley III
# 5                TOT        23.0  48  ...  101   0.663  Marvin Bagley III
# 6                DET        24.0  42  ...  108   0.750  Marvin Bagley III
# 7                DET        25.0  26  ...   61   0.820  Marvin Bagley III
# 8                WAS        25.0  24  ...   65   0.708  Marvin Bagley III
# 9                TOT        25.0  50  ...  126   0.762  Marvin Bagley III
# 10               WAS        26.0  19  ...   23   0.652  Marvin Bagley III
# 11               MEM        26.0  12  ...   12   0.667  Marvin Bagley III
# 12               TOT        26.0  31  ...   35   0.657  Marvin Bagley III
# 13               WAS        26.0  12  ...   18   0.722  Marvin Bagley III
#
#     TOVPG  PFPG  FG3MPG  FG3APG FGMPG  FGAPG  OREBPG
# 0    1.58   1.9    0.48    1.55  5.74  11.39    2.61
# 1    1.38   3.3    0.31    1.69  6.00  12.85    2.23
# 2    1.37   2.3    0.86    2.51  5.74  11.40    2.47
# 3    0.70   1.7    0.50    2.07  3.80   8.20    2.23
# 4    1.00   2.4    0.44    1.94  6.17  11.11    2.11
# 5    0.81   1.9    0.48    2.02  4.69   9.29    2.19
# 6    1.10   1.9    0.45    1.57  4.81   9.10    2.24
# 7    1.12   1.5    0.04    0.23  4.12   6.96    1.77
# 8    1.25   1.7    0.33    0.71  5.50   9.46    3.50
# 9    1.18   1.6    0.18    0.46  4.78   8.16    2.60
# 10   0.58   0.6    0.11    0.53  2.00   3.74    1.42
# 11   0.08   0.5    0.08    0.75  1.42   2.92    0.92
# 12   0.39   0.6    0.10    0.61  1.77   3.42    1.23
# 13   0.92   2.2    0.25    0.50  3.08   4.58    2.00
#
# [14 rows x 25 columns]
# ✓ Marvin Bagley III récupéré
# % de joueurs sélectionnés : 1.69 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.69 %
#  Taille de l'échantillon : 5135
#          Player SEASON_ID  PPG  RPG  APG  BPG  SPG TEAM_ABBREVIATION  \
# 0  Amari Bailey   2023-24  2.3  0.9  0.7  0.0  0.3               CHA
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT        Player  TOVPG  PFPG  FG3MPG  \
# 0        20.0  10  ...    7   0.857  Amari Bailey    0.4   0.2     0.1
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.8   0.8    2.4     0.6
#
# [1 rows x 25 columns]
# ✓ Amari Bailey récupéré
# % de joueurs sélectionnés : 1.71 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.71 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.71 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.71 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.71 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.71 %
#  Taille de l'échantillon : 5135
#              Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Cameron Bairstow   2014-15  0.56  0.44  0.06  0.06  0.11               CHI
# 1  Cameron Bairstow   2015-16  1.89  1.56  0.33  0.17  0.11               CHI
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT            Player  TOVPG  PFPG  FG3MPG  \
# 0        24.0  18  ...    5   0.800  Cameron Bairstow   0.17   0.4    0.00
# 1        25.0  18  ...    8   0.875  Cameron Bairstow   0.22   1.1    0.06
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.00  0.17   0.78    0.33
# 1    0.28  0.72   2.22    0.22
#
# [2 rows x 25 columns]
# ✓ Cameron Bairstow récupéré
# % de joueurs sélectionnés : 1.73 %
#  Taille de l'échantillon : 5135
# ✗ Erreur pour Mark Baker: 'resultSet'
#           Player SEASON_ID  PPG  RPG   APG  BPG   SPG TEAM_ABBREVIATION  \
# 0  Maurice Baker   2004-05  0.0  0.0  0.00  0.0  0.00               LAC
# 1  Maurice Baker   2004-05  0.0  0.5  0.25  0.0  0.25               POR
# 2  Maurice Baker   2004-05  0.0  0.4  0.20  0.0  0.20               TOT
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT         Player  TOVPG  PFPG  FG3MPG  \
# 0        25.0   1  ...    0     0.0  Maurice Baker   0.00   0.0     0.0
# 1        25.0   4  ...    0     0.0  Maurice Baker   0.25   0.8     0.0
# 2        25.0   5  ...    0     0.0  Maurice Baker   0.20   0.6     0.0
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0     0.0   0.0   0.00    0.00
# 1     0.0   0.0   0.25    0.25
# 2     0.0   0.0   0.20    0.20
#
# [3 rows x 25 columns]
# ✓ Maurice Baker récupéré
# % de joueurs sélectionnés : 1.75 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.75 %
#  Taille de l'échantillon : 5135
#       Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Ron Baker   2016-17  4.13  1.88  2.06  0.15  0.65               NYK
# 1  Ron Baker   2017-18  2.45  1.03  1.62  0.21  0.90               NYK
# 2  Ron Baker   2018-19  1.27  0.64  1.18  0.00  0.45               NYK
# 3  Ron Baker   2018-19  0.00  1.00  0.50  0.25  0.25               WAS
# 4  Ron Baker   2018-19  0.93  0.73  1.00  0.07  0.40               TOT
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT     Player  TOVPG  PFPG  FG3MPG  FG3APG  \
# 0        24.0  52  ...   43   0.651  Ron Baker   1.08   1.4    0.44    1.65
# 1        25.0  29  ...   26   0.769  Ron Baker   0.62   1.1    0.38    1.14
# 2        26.0  11  ...    6   0.833  Ron Baker   0.27   1.5    0.09    0.82
# 3        26.0   4  ...    0   0.000  Ron Baker   0.50   0.5    0.00    1.00
# 4        26.0  15  ...    6   0.833  Ron Baker   0.33   1.2    0.07    0.87
#
#   FGMPG  FGAPG  OREBPG
# 0  1.58   4.17    0.23
# 1  0.69   2.03    0.17
# 2  0.36   1.45    0.09
# 3  0.00   1.00    0.00
# 4  0.27   1.33    0.07
#
# [5 rows x 25 columns]
# ✓ Ron Baker récupéré
# % de joueurs sélectionnés : 1.77 %
#  Taille de l'échantillon : 5135
# % de joueurs sélectionnés : 1.77 %
#  Taille de l'échantillon : 5135
#             Player SEASON_ID   PPG   RPG   APG   BPG   SPG TEAM_ABBREVIATION  \
# 0  Wade Baldwin IV   2016-17  3.21  1.39  1.85  0.21  0.55               MEM
# 1  Wade Baldwin IV   2017-18  5.43  1.14  0.71  0.14  0.29               POR
# 2  Wade Baldwin IV   2018-19  1.88  0.94  0.75  0.12  0.06               POR
#
#    PLAYER_AGE  GP  ...  FTA  FT_PCT           Player  TOVPG  PFPG  FG3MPG  \
# 0        21.0  33  ...   37   0.838  Wade Baldwin IV   1.18   1.2    0.09
# 1        22.0   7  ...   10   0.600  Wade Baldwin IV   0.57   1.7    0.57
# 2        23.0  16  ...   11   0.727  Wade Baldwin IV   0.88   0.7    0.12
#
#    FG3APG FGMPG  FGAPG  OREBPG
# 0    0.67  1.09   3.48    0.33
# 1    0.71  2.00   3.00    0.14
# 2    0.56  0.62   2.06    0.12
#
# [3 rows x 25 columns]
# ✓ Wade Baldwin IV récupéré
# % de joueurs sélectionnés : 1.79 %
#  Taille de l'échantillon : 5135
#                 Player SEASON_ID   PPG   RPG   APG   BPG   SPG  \
# 0  Patrick Baldwin Jr.   2022-23  3.94  1.29  0.35  0.13  0.19
# 1  Patrick Baldwin Jr.   2023-24  4.42  3.24  0.76  0.39  0.47
# 2  Patrick Baldwin Jr.   2024-25  2.14  1.00  0.09  0.09  0.14
# 3  Patrick Baldwin Jr.   2024-25  3.00  1.50  0.50  0.00  0.00
# 4  Patrick Baldwin Jr.   2024-25  2.21  1.04  0.12  0.08  0.12
#
#   TEAM_ABBREVIATION  PLAYER_AGE  GP  ...  FTA  FT_PCT               Player  \
# 0               GSW        20.0  31  ...    6   0.667  Patrick Baldwin Jr.
# 1               WAS        21.0  38  ...   28   0.679  Patrick Baldwin Jr.
# 2               WAS        22.0  22  ...    4   0.500  Patrick Baldwin Jr.
# 3               LAC        22.0   2  ...    0   0.000  Patrick Baldwin Jr.
# 4               TOT        22.0  24  ...    4   0.500  Patrick Baldwin Jr.
#
#    TOVPG  PFPG  FG3MPG  FG3APG FGMPG  FGAPG  OREBPG
# 0   0.35   0.5    1.03    2.71  1.39   3.52    0.03
# 1   0.50   1.5    0.82    2.55  1.55   4.08    0.45
# 2   0.23   0.2    0.50    0.95  0.77   1.50    0.23
# 3   0.00   1.0    1.00    1.00  1.00   1.00    0.00
# 4   0.21   0.3    0.54    0.96  0.79   1.46    0.21
#
# [5 rows x 25 columns]
# ✓ Patrick Baldwin Jr. récupéré
# % de joueurs sélectionnés : 1.81 %
#  Taille de l'échantillon : 5135
#  Nombre d'erreurs : 9
